# %% [markdown]
# # Top three features in Bokeh High Charts

# %% [markdown]
# <p style="font-family: &quot;verdana&quot; , sans-serif;">
# Bokeh is an impressive visualization library with a wide audience that ranges from begginers to sophisticated developers.
#
# This is my first part on a series of blog entries about Bokeh.  In this first part, I am addressing the ease of using Bokeh High Level charts.
# <br/>
# <h4> Why these charts are easy </h4>
# </p>
#
# 1. Colors and titles autoselection: don't worry about colors, legends, and axis titles; Bokeh will choose them without extra parameteres.
# 2. Interaction out of the box: the toolbox on the right side can be easily modified.
# 3. Aggregation and groupping as chart attributes: the high-level charts accept an aggregation and groupping attribute so you have to do less data manipulation before charting.

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8e7bdc23-8de9-40e5-9531-8d1dbb403669">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## The data
#
# First let's load some data about diamonds to see easy one-liners high level charts.  This data about 50,000 diamonds comes from the [vincentarelbundock github](https://vincentarelbundock.github.io/Rdatasets/datasets.html)

# %%
import pandas as pd
diamonds = pd.read_csv('./data/diamonds.csv')
diamonds = diamonds.sample(n=1000)
diamonds.head()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 33958       33959   0.23  Very Good     E    VVS1   62.2   59.0    465  3.92
# 18918       18919   1.38      Ideal     F     SI2   62.0   58.0   7767  7.12
# 11647       11648   1.11       Good     I     VS2   63.6   58.0   5054  6.57
# 21608       21609   1.55      Ideal     G     SI2   60.7   55.0   9704  7.54
# 5504         5505   1.11       Good     J     SI1   63.6   58.0   3846  6.48
#
#           y     z
# 33958  3.96  2.45
# 18918  7.17  4.43
# 11647  6.52  4.16
# 21608  7.51  4.57
# 5504   6.57  4.15

# %% [markdown]
# ## 1) Colors autoselection

# %% [markdown]
# In our first example, we see a **scatter plot** defined by the price of diamonds and their carats.  But we are also representing  the cut of the diamond with colors.
#
# I am not passing axis titles or colors as parameters because **they are automatically selected by the Bokeh library**.

# %%
from bokeh.charts import Scatter, Histogram, Bar
p = Scatter(diamonds, color='cut', x='carat', y='price', title='Price of diamonds by carats')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="156b02a2-fa89-4e37-a773-aa0e868bb3eb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("156b02a2-fa89-4e37-a773-aa0e868bb3eb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '156b02a2-fa89-4e37-a773-aa0e868bb3eb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"759293d3-63b4-4fc7-ad02-38fd98666b2c":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"373e67a8-436a-4f02-b019-bab7e3bc653c","type":"Circle"},{"attributes":{"overlay":{"id":"78c0d8fb-af30-421c-b913-82849bb7a538","type":"BoxAnnotation"},"plot":{"id":"4a1f41f3-2979-46e7-8a1a-ac1f01c21668","subtype":"Chart","type":"Plot"}},"id":"b71cbf82-ff7c-440a-9a9e-4100e6c5e9d0","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":20630.6,"start":-1492.6000000000001},"id":"8529697e-4317-4c95-9e6d-15dd53c704bd","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"4a1f41f3-2979-46e7-8a1a-ac1f01c21668","subtype":"Chart","type":"Plot"},"ticker":{"id":"185c6440-3774-4452-bed7-1d5d06bac289","type":"BasicTicker"}},"id":"a8a72339-c355-4b3f-a668-dd2449f9940a","type":"Grid"},{"attributes":{},"id":"59a62e8f-b02f-4be0-8d50-9b27ce5e2f16","type":"ToolEvents"},{"attributes":{"data_source":{"id":"ee293323-8c48-4bfe-a1d9-348a2cd7cb1d","type":"ColumnDataSource"},"glyph":{"id":"373e67a8-436a-4f02-b019-bab7e3bc653c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8d5faabc-e80e-4958-bb98-0aa4536671bb","type":"GlyphRenderer"},{"attributes":{},"id":"f563226f-ad9f-4883-8b67-a6ca24c53d0f","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"},{"cut":"Fair"}],"cut":["Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair","Fair"],"x_values":[0.9,1.03,1.0,0.73,0.7,1.51,0.5,1.02,0.71,2.0,1.01,1.5,2.22,1.51,0.7,1.0,0.81,1.45,1.53,0.73,2.01,1.32,1.01,0.9,0.32,0.7,1.32,1.51,1.03,1.5,0.9,0.8],"y_values":[3697,3743,4480,2317,1672,11102,2579,4462,2208,13764,3280,6006,5607,8387,1115,5331,3323,4570,8996,1802,14799,4140,3871,3145,638,1920,6061,3765,4441,7211,5551,1232]}},"id":"f8f92113-f51f-4737-99fd-1f70be734fef","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"46bc2500-8563-4855-af3c-76cdc53013dd","type":"PanTool"},{"id":"bd9489cc-1c61-4242-8a4b-42358df63988","type":"WheelZoomTool"},{"id":"b71cbf82-ff7c-440a-9a9e-4100e6c5e9d0","type":"BoxZoomTool"},{"id":"926b8ad7-7335-4bf7-a81d-dc9328465628","type":"SaveTool"},{"id":"da205079-1e9c-470a-92cd-52ea9adc3be5","type":"ResetTool"},{"id":"7e33956f-c0ce-41dc-8ba0-40c9972c1f2a","type":"HelpTool"}]},"id":"868d76f0-6e63-492b-9fcb-4e0d0fc14904","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{"cut":"Ideal"},{ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %% [markdown]
# Now... you don't have to get stuck with the default palette.  Bokeh comes with a pre-built list of [palettes](http://bokeh.pydata.org/en/latest/docs/reference/palettes.html#bokeh-palettes).
#
# In the example below we have the same chart but in a palette of greens.

# %%
from bokeh.palettes import YlGn6
from bokeh.charts import Scatter, Histogram, Bar
p = Scatter(diamonds, color='cut', x='carat', y='price', title='Price of diamonds by carats', palette=YlGn6)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c805e9c0-ea7c-45b3-94a8-29ea3d5c4548"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c805e9c0-ea7c-45b3-94a8-29ea3d5c4548");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c805e9c0-ea7c-45b3-94a8-29ea3d5c4548' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2323c30c-e590-4f9b-b242-4a343cc9f806":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Good"},{"cut":"Very Go ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %% [markdown]
# ## 2) Interaction out of the box - the toolbar
# The toolbar is defined by a list of tool names.  You can also modify the location of the toolbar
# through the toolbar_location attribute.
#
# To learn more about the toolbar, including the possible choiced of tools, open [bokeh's documentation page](http://bokeh.pydata.org/en/latest/docs/user_guide/tools.html)

# %%
p = Bar(diamonds, 'cut', values='price', title="Sum of carats per diamond cut", color = 'cut', 
        toolbar_location="right", tools='pan,wheel_zoom, undo')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="4be9451f-e291-40a8-b898-5c15e9202e05"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4be9451f-e291-40a8-b898-5c15e9202e05");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4be9451f-e291-40a8-b898-5c15e9202e05' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %% [markdown]
# ## 3) Groupping and aggregation built-in
#
# The sum of carats shown in the previous chart is not really interesting, and this is where **aggregations** come in.  The **agg** parameter is used in High Level Charts to pass an aggregation method name.  In the chart below I am passing **mean**, but I could have passed in any of the built-in methods: 'sum', 'mean', 'count', 'nunique', 'median', 'min', and 'max'.

# %%
p = Bar(diamonds, 'clarity', values='price', title="Average price per clarity", color = 'clarity', 
        toolbar_location="right", agg='mean')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c1aaff08-40bd-4933-91bf-ab1b032e95ea"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c1aaff08-40bd-4933-91bf-ab1b032e95ea");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c1aaff08-40bd-4933-91bf-ab1b032e95ea' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2ac3755b-22aa-45ed-a005-2e4d5c0b988c":{"roots":{"references":[{"attributes":{},"id":"9e00cd2e-80c0-497c-9709-8f5205d03dce","type":"CategoricalTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1653ef56-b8e3-4edc-9db8-d28b295c00e2","type":"PanTool"},{"id":"f527886a-ffdd-4b89-967a-55ddd21fcedb","type":"WheelZoomTool"},{"id":"dde21400-351f-4016-b3d3-e4b688117e99","type":"BoxZoomTool"},{"id":"a53b9538-c544-4d05-8896-612c21176f61","type":"SaveTool"},{"id":"49b8ad33-09f8-47c0-b916-2aa0694567a9","type":"ResetTool"},{"id":"3f25503b-f9a8-4dc3-968a-e81fc69ccbeb","type":"HelpTool"}]},"id":"529077c7-7316-4702-9a21-b6bbcece8d7a","type":"Toolbar"},{"attributes":{"legends":[["VVS1",[{"id":"e46d0f6d-ab38-4e83-a9a7-071505de8a91","type":"GlyphRenderer"}]],["SI2",[{"id":"a4e3a0d5-859d-4ca1-81e4-372465dcbe77","type":"GlyphRenderer"}]],["VS2",[{"id":"4ee9c8b3-00d1-4b35-89b1-6f3daba87689","type":"GlyphRenderer"}]],["SI1",[{"id":"1f42df82-c9db-4c6c-8210-234addb7ff54","type":"GlyphRenderer"}]],["I1",[{"id":"1e9abd5c-a369-4f21-818a-4c1b75a65cb0","type":"GlyphRenderer"}]],["VS1",[{"id":"b33010d8-b06e-44f9-8fa8-eab4f4f308d7","type":"GlyphRenderer"}]],["VVS2",[{"id":"34718185-c673-48d2-862c-a9ca16827917","type":"GlyphRenderer"}]],["IF",[{"id":"c5e8cce5-beff-4b3c-aad4-9f0fdd6a2d2f","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"1f69728c-be7f-4a9c-b62d-62518f22313f","subtype":"Chart","type":"Plot"}},"id":"71eee237-cdf4-492a-ad56-c5881eb0b45f","type":"Legend"},{"attributes":{},"id":"7855a9e9-ea30-4222-a747-8e713454f632","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f856659-312b-4fd3-88ca-72b14ea82f1e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a66020a1-6511-4228-bb48-e1005ef02633","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"57a649f7-92d7-4266-bf6c-c91dd348461e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b661830a-c1a8-45e5-a4d9-b92015532434","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"124cb7ae-762a-4d3b-84eb-fbf554857206","type":"Rect"},{"attributes":{"data_source":{"id":"43377568-a633-4f12-9e89-ca26f6705e40","type":"ColumnDataSource"},"glyph":{"id":"124cb7ae-762a-4d3b-84eb-fbf554857206","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b33010d8-b06e-44f9-8fa8-eab4f4f308d7","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"clarity":"VVS2"}],"clarity":["VVS2"],"color":["#5ab738"],"fill_alpha":[0.8],"height":[3022.3164556962024],"label":[{"clarity":"VVS2"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["VVS2"],"y":[1511.1582278481012]}},"id":"17011c87-8bd5-4aa8-85c8-4cfe3692c2c0","type":"ColumnDataSource"},{"attributes":{},"id":"279e7182-562b-4880-b159-8d36f596c98b","type":"BasicTickFormatter"},{"attribut ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %% [markdown]
# Another nice feature is **groupping**, which in tandem with aggregations, can provide further insight into the displayed data.  For instance, in the chart below we are again showing the average price per clarity, but now groupped per cut type.

# %%
p = Bar(diamonds, 'clarity', values='price', title="Avg price per cut and clarity", color = 'cut', 
        toolbar_location="right", agg='mean', group='cut', legend="top_right")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1018adc0-4182-491b-991f-1881b6848891"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1018adc0-4182-491b-991f-1881b6848891");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1018adc0-4182-491b-991f-1881b6848891' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"00246029-6e64-4f45-9948-4b8fd24e232c":{"roots":{"references":[{"attributes":{"data_source":{"id":"f944d221-af66-43f8-99f8-3f9745cbef97","type":"ColumnDataSource"},"glyph":{"id":"133d1b85-7649-4ef7-91ca-f90ff3eed3b6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1573fc99-c0ee-46ef-9197-120f1cb0febd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7f2424cf-a0ad-4013-bced-b461dcb7c554","type":"ColumnDataSource"},"glyph":{"id":"c9731e47-ed4c-4432-b0c0-c0fd384a3d8d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"19d57270-bcdc-4155-8230-a95686ce2c3b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"clarity":"SI2","cut":"Ideal"}],"clarity":["SI2"],"color":["#407ee7"],"cut":["Ideal"],"fill_alpha":[0.8],"height":[4944.535714285715],"label":[{"clarity":"SI2","cut":"Ideal"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.17026798450415692],"x":["SI2:0.333333333333"],"y":[2472.2678571428573]}},"id":"ed976af9-5081-4e02-a7da-d7010fcadbcb","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fed9df4b-ddcd-49b1-812b-067614b9a89a","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8987289a-1d2d-4672-887c-2e04c7020d46","type":"Rect"},{"attributes":{},"id":"b98d51c9-cea5-42d5-a5e9-8757bf8de92f","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"259eb45b-0982-40a2-a84c-5b7f2b7f298f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6343ea49-a518-4965-92a4-ed595f384eae","type":"Rect"},{"attributes":{"data_source":{"id":"30cd63b1-3b44-4596-9066-19051a624af9","type":"ColumnDataSource"},"glyph":{"id":"6343ea49-a518-4965-92a4-ed595f384eae","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8bf9af5d-c260-41e0-8a9e-c336c085cbcd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6abc83be-54c8-423f-b20a-bf38b1c202fd","type":"ColumnDataSource"},"glyph":{"id":"0100b91d-b20a-4c9f-a571-aedb8bb44b70","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"31ff249c-f2ee-456a-ad43-a8b59b862885","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b0029273-396f-4f09-8814-663309944ec2","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c8d71322-a684-476c-aadb-b0dfdd1f2d76","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7233bed6-b20a-4ba1-8861-3e988eea837d","type ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>
