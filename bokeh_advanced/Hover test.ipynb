# %%
from bokeh.plotting import figure, show,output_notebook
from bokeh.models import ColumnDataSource, HoverTool, CustomJS

output_notebook()
#output_file("hover_callback.html")

# define some points and a little graph between them
x = [2, 3, 5, 6, 8, 7]
y = [6, 4, 3, 8, 7, 5]
links = {
    0: [1, 2],
    1: [0, 3, 4],
    2: [0, 5],
    3: [1, 4],
    4: [1, 3],
    5: [2, 3, 4]
}

p = figure(width=400, height=400, tools="", toolbar_location=None, title='Hover over points')

source = ColumnDataSource({'x0': [], 'y0': [], 'x1': [], 'y1': []})
sr = p.segment(x0='x0', y0='y0', x1='x1', y1='y1', color='olive', alpha=0.6, line_width=3, source=source, )
cr = p.circle(x, y, color='olive', size=30, alpha=0.4, hover_color='olive', hover_alpha=1.0)

# Add a hover tool, that sets the link data for a hovered circle
code = """
var links = %s;
var data = {'x0': [], 'y0': [], 'x1': [], 'y1': []};
var cdata = circle.get('data');
var indices = cb_data.index['1d'].indices;
for (i=0; i < indices.length; i++) {
    alert(JSON.stringify(cb_data));
    ind0 = indices[i]
    for (j=0; j < links[ind0].length; j++) {
        ind1 = links[ind0][j];
        data['x0'].push(cdata.x[ind0]);
        data['y0'].push(cdata.y[ind0]);
        data['x1'].push(cdata.x[ind1]);
        data['y1'].push(cdata.y[ind1]);
    }
}
segment.set('data', data);
""" % links

callback = CustomJS(args={'circle': cr.data_source, 'segment': sr.data_source}, code=code)
p.add_tools(HoverTool(tooltips=None, callback=callback, renderers=[cr]))

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8a4e5f14-092c-4829-9026-15038dc4a575">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="31715655-8744-45da-930a-6ff69634f771"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("31715655-8744-45da-930a-6ff69634f771");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '31715655-8744-45da-930a-6ff69634f771' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a0121128-cc9e-4f9a-8869-06d7b1688238":{"roots":{"references":[{"attributes":{"plot":{"id":"38a8ccf1-d366-4b8c-bcf0-f541bd86ea7c","subtype":"Figure","type":"Plot"},"ticker":{"id":"76461188-4ce7-4bf9-b969-ff4fe6ff7562","type":"BasicTicker"}},"id":"43d7b17a-a61c-4aa4-b9cc-62db65072d66","type":"Grid"},{"attributes":{"plot":null,"text":"Hover over points"},"id":"cf306f78-6793-40fd-8364-37b6ec60db9d","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"492dcb7a-99c1-4f22-a436-6ff39fb45dbf","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x0":{"field":"x0"},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"eea910c9-1704-4163-803e-5b736a8b5fd2","type":"Segment"},{"attributes":{"callback":null,"column_names":["y1","y0","x0","x1"],"data":{"x0":[],"x1":[],"y0":[],"y1":[]}},"id":"1a4945d7-acde-443a-a677-d41a8c7635b7","type":"ColumnDataSource"},{"attributes":{},"id":"7d98102d-3583-4dc2-9554-f183f3536266","type":"BasicTickFormatter"},{"attributes":{},"id":"76461188-4ce7-4bf9-b969-ff4fe6ff7562","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"olive"},"line_color":{"value":"olive"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"a2b27e61-48ac-40e2-9c50-a3e4a47486ea","type":"Circle"},{"attributes":{},"id":"877035a7-e718-4e51-b7d9-52aea8808200","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"698036e5-b087-4071-864a-3c32841c40ac","type":"LinearAxis"}],"left":[{"id":"af3f591f-18f8-4e7b-9e33-d8e08272ac44","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"698036e5-b087-4071-864a-3c32841c40ac","type":"LinearAxis"},{"id":"43d7b17a-a61c-4aa4-b9cc-62db65072d66","type":"Grid"},{"id":"af3f591f-18f8-4e7b-9e33-d8e08272ac44","type":"LinearAxis"},{"id":"26e62c0d-c90c-4a37-af5d-7da59365e29b","type":"Grid"},{"id":"e8cf14a5-1552-4cd5-a89f-00d3b8fb5ed2","type":"GlyphRenderer"},{"id":"7c0e77bf-164b-4212-a7cb-633d3acc5bdb","type":"GlyphRenderer"}],"title":{"id":"cf306f78-6793-40fd-8364-37b6ec60db9d","type":"Title"},"tool_events":{"id":"53bcf35d-7dba-40dc-89b0-ddaf3000ce47","type":"ToolEvents"},"toolbar":{"id":"f775ad6b-584c-40e6-b594-fdfe26151970","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"e4247689-d3c7-406f-bc49-ffcf506195de","type":"DataRange1d"},"y_range":{"id":"6ea9a16e-addd-47d9-a8b0-38330d909b9b","type":"DataRange1d"}},"id":"38a8ccf1-d366-4b8c-bcf0-f541bd86ea7c","subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.6},"line_color":{"value":"olive"},"line_width":{"value":3},"x0":{"field":"x0"},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"4c0975bd-c6a2-44a0-af16-660bf8df0cbc","type":"Segment"},{"attributes":{},"id":"7f68c5bf-6e43-415d-98db-049d524601a3","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.4},"fill_color":{"value":"olive"},"line_alpha":{"value":0.4},"line_color":{"value":"olive"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"c9bcdbce-5748-47b0-813a-6d061aaca1ad","type":"Circle"},{"attributes":{"data_source":{"id":"dd89cefe-2418-4b82-8239-613292182ca0","type":"ColumnDataSource"},"glyph":{"id":"c9bcdbce-5748-47b0-813a-6d061aaca1ad","type":"Circle"},"hover_glyph":{"id":"a2b27e61-48ac-40e2-9c50-a3e4a47486ea","type":"Circle"},"nonselection_glyph":{"id":"492dcb7a-99c1-4f22-a436-6ff39fb45dbf","type":"Circle"},"selection_glyph":null},"id":"7c0e77bf-164b-4212-a7cb-633d3acc5bdb","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"6ea9a16e-addd-47d9-a8b0-38330d909b9b","type":"DataRange1d"},{"attributes":{"formatter":{"id":"877035a7-e718-4e51-b7d9-52aea8808200","type":"BasicTickFormatter"},"plot":{"id":"38a8ccf1-d366-4b8c-bcf0-f541bd86ea7c","subtype":"Figure","type":"Plot"},"ticke ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>
